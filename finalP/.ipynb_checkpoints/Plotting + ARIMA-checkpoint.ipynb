# %%
# https://pypi.org/project/yahoofinancials/
#df_yahoo = yf.download('EURUSD=X', # using Yahoo Finance API download() function
#start='2020-01-01',
#end='2022-31-11',
#progress=False)

#f = web.DataReader("AAPL", "av-daily", start=datetime(2017, 2, 9),
#                   end=datetime(2017, 5, 24),
#                   api_key=os.getenv('ALPHAVANTAGE_API_KEY'))

#df = pdr.get_data_tiingo('GOOG', api_key=os.getenv('TIINGO_API_KEY'))
#df.head()

# %%
ALPHAVANTAGE_API_KEY = "62SMMIM56VVI1TX8"
# https://www.alphavantage.co/support/#api-key
#https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %%
# initial attempt, not needed as it's apple stock
f = web.DataReader("AAPL", "yahoo", start=datetime(2017, 2, 9),
                   end=datetime(2017, 5, 24),
                   )

f.loc["2017-02-09"]

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

import os
from datetime import datetime
import pandas_datareader.data as web
#from pandas_datareader import data 

# Visualisation
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("seaborn-colorblind")

from pandas_datareader import data as web
from pandas import Series, DataFrame
import datetime
from operator import itemgetter # constructs a callable that assumes an iterable object (e.g. list, tuple, set) as input, and fetches the n-th element out of it.
from datetime import datetime
from datetime import datetime, timedelta

import statsmodels.api as sm

# %%
eur = web.DataReader("EURUSD=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
eur['Currency'] = 'EUR'
eur.head()
# Out:
#                 High       Low      Open     Close  Volume  Adj Close Currency
# Date
# 2003-12-01  1.204007  1.194401  1.203398  1.196501     0.0   1.196501      EUR
# 2003-12-02  1.210903  1.194600  1.196101  1.208897     0.0   1.208897      EUR
# 2003-12-03  1.213003  1.207700  1.209000  1.212298     0.0   1.212298      EUR
# 2003-12-04  1.214403  1.204398  1.212004  1.208094     0.0   1.208094      EUR
# 2003-12-05  1.219096  1.206593  1.207802  1.218695     0.0   1.218695      EUR

# %%
gbp = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
gbpusd['Currency'] = 'GBP'
gbpusd.head()
# Out:
#                 High       Low      Open     Close  Volume  Adj Close Currency
# Date
# 2003-12-01  1.727205  1.718390  1.723811  1.718597     0.0   1.718597      GBP
# 2003-12-02  1.732112  1.717298  1.719010  1.730313     0.0   1.730313      GBP
# 2003-12-03  1.731812  1.725209  1.730493  1.728101     0.0   1.728101      GBP
# 2003-12-04  1.728997  1.718302  1.727414  1.720697     0.0   1.720697      GBP
# 2003-12-05  1.733102  1.719809  1.720608  1.733102     0.0   1.733102      GBP

# %%
eurgbp = web.DataReader("EURGBP=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
eurgbp['Currency'] = 'EUR'
eurgbp.head()
# Out:
#               High     Low    Open   Close  Volume  Adj Close Currency
# Date
# 2000-01-03  0.6290  0.6203  0.6239  0.6254     0.0     0.6254      EUR
# 2000-01-04  0.6314  0.6236  0.6253  0.6283     0.0     0.6283      EUR
# 2000-01-05  0.6330  0.6268  0.6281  0.6284     0.0     0.6284      EUR
# 2000-01-06  0.6316  0.6242  0.6296  0.6259     0.0     0.6259      EUR
# 2000-01-07  0.6294  0.6235  0.6265  0.6284     0.0     0.6284      EUR

# %%
gbpjpy = web.DataReader("GBPJPY=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
gbpjpy['Currency'] = 'JPY'
gbpjpy.head()
# Out:
#                   High         Low        Open       Close  Volume  \
# Date
# 2003-12-01  189.660004  187.740005  189.330002  187.630005     0.0
# 2003-12-02  188.809998  187.559998  187.669998  188.009995     0.0
# 2003-12-03  188.240005  186.490005  188.020004  187.089996     0.0
# 2003-12-04  187.029999  185.899994  187.029999  186.220001     0.0
# 2003-12-05  186.740005  185.830002  186.190002  185.880005     0.0
#
#              Adj Close Currency
# Date
# 2003-12-01  187.630005      JPY
# 2003-12-02  188.009995      JPY
# 2003-12-03  187.089996      JPY
# 2003-12-04  186.220001      JPY
# 2003-12-05  185.880005      JPY

# %%
#tickers = ['EURGBP=X', 'GBPUSD=X']
#start = "2012-10-31"
#end = "2022-10-31"
#testdata = web.DataReader(tickers, 'yahoo', start=start, end=end)
#testdata

# %% [markdown]
# # Giving up for now - moving on

# %%
plt.figure(figsize=(15, 8))
plt.title('EURGBP=X high vs low')
plt.plot(eurgbp['High'], label='High')
plt.plot(eurgbp['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('EUR/GBP rate')
plt.legend()

# %%
plt.figure(figsize=(15, 8))
plt.title('GBPUSD=X high vs low')
plt.plot(gbp['High'], label='High')
plt.plot(gbp['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('EUR/USD rate')
plt.legend()

# %%
print('mean :' , gbp.Close.mean())
res = sm.tsa.seasonal_decompose(gbp.Close, period=360)
resplot = res.plot()

resplot.set_size_inches((14,9))
resplot.tight_layout()
# Out:
# mean : 1.5585386933871317

# %%
gbp15 = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2015, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
gbp15
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2015-01-01  1.558094  1.558094  1.558094  1.558094     0.0   1.558094
# 2015-01-02  1.558458  1.538746  1.558021  1.557972     0.0   1.557972
# 2015-01-05  1.532004  1.520612  1.528608  1.528491     0.0   1.528491
# 2015-01-06  1.527370  1.515795  1.525832  1.525832     0.0   1.525832
# 2015-01-07  1.515611  1.506796  1.513638  1.513798     0.0   1.513798
# ...              ...       ...       ...       ...     ...        ...
# 2022-10-24  1.149954  1.127370  1.130544  1.130774     0.0   1.130774
# 2022-10-25  1.162358  1.143419  1.146066  1.146224     0.0   1.146224
# 2022-10-26  1.164415  1.155095  1.163345  1.163819     0.0   1.163819
# 2022-10-27  1.160012  1.150616  1.156738  1.156604     0.0   1.156604
# 2022-10-31  1.161116  1.147776  1.159434  1.150139     0.0   1.150139
#
# [2040 rows x 6 columns]

# %%
#import statsmodels.api as sm
print('mean :' , gbp15.Close.mean())
res = sm.tsa.seasonal_decompose(gbp15.Close, period=360)
resplot = res.plot()

resplot.set_size_inches((14,9))
resplot.tight_layout()
# Out:
# mean : 1.3385186426779803

# %% [markdown]
# # trying deep learning

# %%
import matplotlib.pyplot as plt

from tensorflow.python import tf2
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical
# Out:
# 2022-10-31 17:56:51.549326: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def load_data(path):
    with np.load(path) as f:
        x_train, y_train = f['x_train'], f['y_train']
        x_test, y_test = f['x_test'], f['y_test']
        return (x_train, y_train), (x_test, y_test)

(train_images, train_labels), (test_images, test_labels) = load_data('mnist.npz')

# %%
column_indices = {name: i for i, name in enumerate(gbp15.columns)}
n = len(gbp15)
train_df = gbp15[0:int(n*0.7)]
val_df = gbp15[int(n*0.7):int(n*0.9)]
test_df = gbp15[int(n*0.9):]

# %%
train_mean = train_df.mean()
train_std = train_df.std()
train_df = (train_df - train_mean) / train_std
val_df = (val_df - train_mean) / train_std
test_df = (test_df - train_mean) / train_std

# %%
import seaborn as sns #, kde=True puts the line in
df_std = (df - train_mean) / train_std
df_std = df_std.melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
_ = ax.set_xticklabels(df.keys(), rotation=90)

# %% [markdown]
# # Model 1: Long Short-Term Memory ( LSTM ) machine learning

# %%
import math
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
gbpnew = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
gbpnew
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2003-12-01  1.727205  1.718390  1.723811  1.718597     0.0   1.718597
# 2003-12-02  1.732112  1.717298  1.719010  1.730313     0.0   1.730313
# 2003-12-03  1.731812  1.725209  1.730493  1.728101     0.0   1.728101
# 2003-12-04  1.728997  1.718302  1.727414  1.720697     0.0   1.720697
# 2003-12-05  1.733102  1.719809  1.720608  1.733102     0.0   1.733102
# ...              ...       ...       ...       ...     ...        ...
# 2022-10-24  1.149954  1.127370  1.130544  1.130774     0.0   1.130774
# 2022-10-25  1.162358  1.143419  1.146066  1.146224     0.0   1.146224
# 2022-10-26  1.164415  1.155095  1.163345  1.163819     0.0   1.163819
# 2022-10-27  1.160012  1.150616  1.156738  1.156604     0.0   1.156604
# 2022-10-31  1.161116  1.146092  1.159434  1.146776     0.0   1.146776
#
# [4919 rows x 6 columns]

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP / USD historical exchange rate')
plt.plot(gbpnew['Close'])
plt.xlabel('Date')
plt.ylabel('Close value')
# Out:
# Text(0, 0.5, 'Close value')

# %%
close_prices = gbpnew['Close']
values = close_prices.values
training_data_len = math.ceil(len(values)* 0.8) # rounds a number UP to the nearest integer 

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(values.reshape(-1,1)) # reshape the scaled data into a two-dimensional array

train_data = scaled_data[0: training_data_len, :]

x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0]) # following a random 60 days data window
    y_train.append(train_data[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train) 
# Convert the feature data np array as it is the data format accepted by the Tensorflow when training 
# a neural network model

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1)) 
# Reshape again the x_train and y_train into a three-dimensional array as part of the requirement to 
# train a LSTM model

# %%
test_data = scaled_data[training_data_len-60: , : ]
x_test = []
y_test = values[training_data_len:]

for i in range(60, len(test_data)):
  x_test.append(test_data[i-60:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ### Setting up the machine learning network arhitecture

# %%
# %%time
model = keras.Sequential()
model.add(layers.LSTM(100, return_sequences=True, input_shape=(x_train.shape[1], 1))) # return=True so the output of the layer will be another sequence of the same length
model.add(layers.LSTM(100, return_sequences=False)) # reture=false to only return the last output in the output sequence
model.add(layers.Dense(25))
model.add(layers.Dense(1))
model.summary()
# Out:
# 2022-10-31 18:29:30.362172: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 100)           40800
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 25)                2525
#
#  dense_1 (Dense)             (None, 1)                 26
#
# ...
# Total params: 123,751
# Trainable params: 123,751
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 1.31 s, sys: 205 ms, total: 1.51 s
# Wall time: 2.62 s

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, batch_size= 1, epochs=3)
# Out:
# Epoch 1/3
# 3876/3876 [==============================] - 201s 49ms/step - loss: 9.1161e-04
# Epoch 2/3
# 3876/3876 [==============================] - 197s 51ms/step - loss: 3.5405e-04
# Epoch 3/3
# 3876/3876 [==============================] - 233s 60ms/step - loss: 2.7950e-04

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 31/31 [==============================] - 4s 73ms/step
# 0.00409677627734226

# %%
data = gbpnew.filter(['Close'])
train = data[:training_data_len]
validation = data[training_data_len:]
validation['Predictions'] = predictions
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('GBP / USD exchange rate')
plt.plot(train)
plt.plot(validation[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower left')
plt.show()
# Out:
# /var/folders/0j/8qpr4dtj39x29g5tw9dvh26m0000gn/T/ipykernel_7657/595970932.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation['Predictions'] = predictions

# %% [markdown]
# # trying building ARIMA model

# %% [markdown]
# Autoregressive Integrated Moving Average (ARIMA): Auto Regressive Integrated Moving Average, ARIMA, is actually a class of models that ‘explains’ a given time series based on its own past values, that is, its own lags and the lagged forecast errors, so that equation can be used to forecast future values.

# %%
import warnings
warnings.filterwarnings('ignore')

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
gbpnew
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2003-12-01  1.727205  1.718390  1.723811  1.718597     0.0   1.718597
# 2003-12-02  1.732112  1.717298  1.719010  1.730313     0.0   1.730313
# 2003-12-03  1.731812  1.725209  1.730493  1.728101     0.0   1.728101
# 2003-12-04  1.728997  1.718302  1.727414  1.720697     0.0   1.720697
# 2003-12-05  1.733102  1.719809  1.720608  1.733102     0.0   1.733102
# ...              ...       ...       ...       ...     ...        ...
# 2022-10-24  1.149954  1.127370  1.130544  1.130774     0.0   1.130774
# 2022-10-25  1.162358  1.143419  1.146066  1.146224     0.0   1.146224
# 2022-10-26  1.164415  1.155095  1.163345  1.163819     0.0   1.163819
# 2022-10-27  1.160012  1.150616  1.156738  1.156604     0.0   1.156604
# 2022-10-31  1.161116  1.146092  1.159434  1.146776     0.0   1.146776
#
# [4919 rows x 6 columns]

# %%
# Visualize the daily closing price.
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(gbpnew['Close'])
plt.title('GBP / USD Closing price')
plt.show()

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(gbpnew['Close'])
# Out:
# Results of dickey fuller test
# Test Statistics                  -0.909316
# p-value                           0.784889
# No. of lags used                  0.000000
# Number of observations used    4918.000000
# critical value (1%)              -3.431680
# critical value (5%)              -2.862128
# critical value (10%)             -2.567083
# dtype: float64

# %%
#To separate the trend and the seasonality from a time series, 
# we can decompose the series using the following code.
result = seasonal_decompose(gbpnew['Close'], model='multiplicative', period = 365)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
#if not stationary then eliminate trend
#Eliminate trend
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(gbpnew['Close'])
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# making ARMIA
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
# Auto ARIMA: Automatically discover the optimal order for an ARIMA model.

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-32660.645, Time=1.44 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-32661.181, Time=2.98 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-32661.129, Time=1.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-32662.248, Time=0.60 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-32659.372, Time=4.25 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 10.445 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 4424
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               16332.124
# Date:                Mon, 31 Oct 2022   AIC                         -32662.248
# Time:                        22:30:32   BIC                         -32655.854
# Sample:                             0   HQIC                        -32659.993
#                                - 4424
# ...

# %%
# Build Model
model = ARIMA(train_data, order=(0,1,0))  
fitted = model.fit() #(disp=-1)  disp is optional boolean
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 4424
# Model:                 ARIMA(0, 1, 0)   Log Likelihood               16332.124
# Date:                Mon, 31 Oct 2022   AIC                         -32662.248
# Time:                        22:40:38   BIC                         -32655.854
# Sample:                             0   HQIC                        -32659.993
#                                - 4424
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.632e-05   3.23e-07    112.463      0.000    3.57e-05     3.7e-05
# ...
# Ljung-Box (L1) (Q):                   2.54   Jarque-Bera (JB):             16720.01
# Prob(Q):                              0.11   Prob(JB):                         0.00
# ...

# %%
# Forecast
fc = fitted.forecast(492, alpha=0.05)  # 95% conf

# %%
conf
# Out:
# 4424    0.290205
# 4425    0.290205
# 4426    0.290205
# 4427    0.290205
# 4428    0.290205
#           ...
# 4740    0.290205
# 4741    0.290205
# 4742    0.290205
# 4743    0.290205
# 4744    0.290205
# Name: predicted_mean, Length: 321, dtype: float64

# %%
test_data
# Out:
# Date
# 2020-12-11    0.285604
# 2020-12-14    0.286549
# 2020-12-15    0.287495
# 2020-12-16    0.295983
# 2020-12-17    0.300322
#                 ...
# 2022-10-24    0.122902
# 2022-10-25    0.136473
# 2022-10-26    0.151707
# 2022-10-27    0.145488
# 2022-10-31    0.136954
# Name: Close, Length: 492, dtype: float64

# %%
fc
# Out:
# 4424    0.290205
# 4425    0.290205
# 4426    0.290205
# 4427    0.290205
# 4428    0.290205
#           ...
# 4740    0.290205
# 4741    0.290205
# 4742    0.290205
# 4743    0.290205
# 4744    0.290205
# Name: predicted_mean, Length: 321, dtype: float64

# %%
# report performance
import math

mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))

mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))

rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))

mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# MSE: 0.004727766133764097
# MAE: 0.05027411763936188
# RMSE: 0.06875875314288427
# MAPE: nan

# %%
https://www.analyticsvidhya.com/blog/2021/07/stock-market-forecasting-using-time-series-analysis-with-arima-model/
